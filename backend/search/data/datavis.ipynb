# %% [markdown]
# ### Data visualization to help with cleaning and normalization

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import os

df = pd.read_csv("places.csv")

# Remove CaseNum, Long, Lat, StNum
df = df.drop(['CaseNum', 
              'Long',
              'Lat',
              'StNum'],
              axis = 1)

df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'Climate'}>,
#         <Axes: title={'center': 'HousingCost'}>,
#         <Axes: title={'center': 'HlthCare'}>],
#        [<Axes: title={'center': 'Crime'}>,
#         <Axes: title={'center': 'Transp'}>,
#         <Axes: title={'center': 'Educ'}>],
#        [<Axes: title={'center': 'Arts'}>,
#         <Axes: title={'center': 'Recreat'}>,
#         <Axes: title={'center': 'Econ'}>],
#        [<Axes: title={'center': 'Pop'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df = pd.read_csv("places_z_score.csv")

df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Climate'}>,
#         <Axes: title={'center': 'HousingCost'}>,
#         <Axes: title={'center': 'HlthCare'}>],
#        [<Axes: title={'center': 'Crime'}>,
#         <Axes: title={'center': 'Transp'}>,
#         <Axes: title={'center': 'Educ'}>],
#        [<Axes: title={'center': 'Arts'}>,
#         <Axes: title={'center': 'Recreat'}>,
#         <Axes: title={'center': 'Econ'}>],
#        [<Axes: title={'center': 'Pop'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df = pd.read_csv("places_min_max.csv")

df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Climate'}>,
#         <Axes: title={'center': 'HousingCost'}>,
#         <Axes: title={'center': 'HlthCare'}>],
#        [<Axes: title={'center': 'Crime'}>,
#         <Axes: title={'center': 'Transp'}>,
#         <Axes: title={'center': 'Educ'}>],
#        [<Axes: title={'center': 'Arts'}>,
#         <Axes: title={'center': 'Recreat'}>,
#         <Axes: title={'center': 'Econ'}>],
#        [<Axes: title={'center': 'Pop'}>, <Axes: >, <Axes: >]],
#       dtype=object)
